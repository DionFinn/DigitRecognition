# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os

os.makedirs("./SEQ", exist_ok=True)
# Out:
# 2025-11-24 12:36:41.975571: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_test = x_test.astype("float32") / 255.0
x_train = x_train.astype("float32") / 255.0

print(x_test.shape)
print(y_test.shape)
# Out:
# (10000, 28, 28)
# (10000,)

# %%
model = keras.Sequential([
    layers.Input(shape=(28, 28, 1), name="input"),
    layers.Conv2D(32, (5, 5), activation="relu"),
    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dense(128, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
train = model.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=10,
    shuffle=True,
    validation_split=0.1
    )
# Out:
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.9946 - loss: 0.0165 - val_accuracy: 0.9860 - val_loss: 0.0482
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.9960 - loss: 0.0120 - val_accuracy: 0.9857 - val_loss: 0.0581
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.9964 - loss: 0.0101 - val_accuracy: 0.9848 - val_loss: 0.0605
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 16s 38ms/step - accuracy: 0.9971 - loss: 0.0090 - val_accuracy: 0.9825 - val_loss: 0.0713
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 17s 39ms/step - accuracy: 0.9976 - loss: 0.0074 - val_accuracy: 0.9842 - val_loss: 0.0652
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.9964 - loss: 0.0102 - val_accuracy: 0.9832 - val_loss: 0.0715
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.9976 - loss: 0.0074 - val_accuracy: 0.9840 - val_loss: 0.0635
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.9981 - loss: 0.0060 - val_accuracy: 0.9795 - val_loss: 0.1032
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.9984 - loss: 0.0051 - val_accuracy: 0.9872 - val_loss: 0.0611
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 0.9852 - val_loss: 0.0718

# %%
filepath = "./SEQ/sequential.keras"
model.save(filepath)
